# %%
import pandas as pd
from pygments import highlight
from pygments.lexers import SparqlLexer
from pygments.formatters import HtmlFormatter
from IPython.display import HTML
from rdflib import Graph

def run_query(graph, query_path):
    try:
        with open(query_path, 'r') as file:
            query = file.read()
    except Exception as _e:
        print(f"No file for {query_path}")
        return
    results = graph.query(query)
    # Display the SPARQL query
    formatted_query = highlight(query, SparqlLexer(), HtmlFormatter(style='solarized-dark', full=True, nobackground=True))
    display(HTML(formatted_query))
    # Convert results to a Pandas DataFrame
    res_list = []
    for row in results:
        res_list.append([str(item) for item in row])
    df = pd.DataFrame(res_list, columns=[str(var) for var in results.vars]) if len(res_list) > 0 else pd.DataFrame()
    # Display the DataFrame as a table in Jupyter Notebook
    display(HTML(df.to_html()))

g = Graph(store="Oxigraph")
g.parse("minecraft.ttl")

print(f"Working with {len(g)} triples")
# Out:
# Working with 36187 triples

# %%
# Run a query
run_query(g, "queries/test.rq")
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">SELECT</span> <span class="nv">?recipeName</span> <span class="nv">?itemName</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?recipe</span> <span class="nn">rdf</span><span class="p">:</span><span class="nt">type</span> <span class="nn">mc</span><span class="p">:</span><span class="nt">Recipe</span> <span class="p">.</span>
#   <span class="nv">?recipe</span> <span class="nn">mc</span><span class="p">:</span><span class="nt">hasName</span> <span class="nv">?recipeName</span> <span class="p">.</span>
#   <span class="nv">?recipe</span> <span class="nn">mc_recipe</span><span class="p">:</span><span class="nt">makesItem</span> <span class="nv">?item</span> <span class="p">.</span>
#   <span class="nv">?item</span> <span class="nn">mc</span><span class="p">:</span><span class="nt">hasId</span> <span class="nv">?itemName</span> <span class="p">.</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>recipeName</th>
#       <th>itemName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>purple_stained_glass_pane</td>
#       <td>475</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>oxidized_cut_copper_stairs_from_oxidized_cut_copper_stonecutting</td>
#       <td>89</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>raw_iron_block</td>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>golden_boots</td>
#       <td>835</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>waxed_oxidized_cut_copper_stairs_from_waxed_oxidized_copper_stonecutting</td>
#       <td>105</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>stripped_cherry_wood</td>
#       <td>138</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>oak_pressure_plate</td>
#       <td>677</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>acacia_fence_gate</td>
#       <td>716</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>cracked_nether_bricks</td>
#       <td>345</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>cut_sandstone_slab_from_cut_sandstone_stonecutting</td>
#       <td>245</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>green_glazed_terracotta</td>
#       <td>530</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>weathered_cut_copper_stairs_from_weathered_cut_copper_stonecutting</td>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>mangrove_door</td>
#       <td>696</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>pink_stained_glass_pane</td>
#       <td>471</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>cut_sandstone_from_sandstone_stonecutting</td>
#       <td>171</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>polished_blackstone_bricks_from_polished_blackstone_stonecutting</td>
#       <td>1185</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>dye_brown_carpet</td>
#       <td>436</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>gold_nugget_from_blasting</td>
#       <td>955</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>mangrove_boat</td>
#       <td>750</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>lead</td>
#       <td>1082</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>sandstone</td>
#       <td>169</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>dye_black_carpet</td>
#       <td>439</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>orange_dye_from_red_yellow</td>
#       <td>905</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>spruce_hanging_sign</td>
#       <td>858</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>weathered_cut_copper_slab</td>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>powered_rail</td>
#       <td>723</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>light_gray_concrete_powder</td>
#       <td>557</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>dripstone_block</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>black_candle</td>
#       <td>1206</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>purpur_stairs</td>
#       <td>275</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>cooked_salmon_from_campfire_cooking</td>
#       <td>900</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>eye_armor_trim_smithing_template</td>
#       <td>1224</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>warped_door</td>
#       <td>699</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>blackstone_stairs_from_blackstone_stonecutting</td>
#       <td>1179</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>stone_brick_wall_from_stone_bricks_stonecutting</td>
#       <td>382</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>quartz_slab_from_stonecutting</td>
#       <td>252</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>mud_brick_wall</td>
#       <td>383</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>iron_chestplate</td>
#       <td>825</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>dye_brown_wool</td>
#       <td>192</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>smooth_sandstone_stairs_from_smooth_sandstone_stonecutting</td>
#       <td>606</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>glass_pane</td>
#       <td>335</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>shears</td>
#       <td>942</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>dark_oak_chest_boat</td>
#       <td>749</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>acacia_wood</td>
#       <td>148</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>diamond_chestplate</td>
#       <td>829</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>light_weighted_pressure_plate</td>
#       <td>675</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>cobbled_deepslate_slab</td>
#       <td>630</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>green_concrete_powder</td>
#       <td>562</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>soul_torch</td>
#       <td>309</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>golden_shovel</td>
#       <td>788</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>comparator</td>
#       <td>639</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>blue_stained_glass_pane_from_glass_pane</td>
#       <td>476</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>stripped_jungle_wood</td>
#       <td>136</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>melon</td>
#       <td>336</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>golden_helmet</td>
#       <td>832</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>white_stained_glass_pane_from_glass_pane</td>
#       <td>465</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>birch_fence_gate</td>
#       <td>714</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>brown_stained_glass_pane</td>
#       <td>477</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>yellow_dye_from_sunflower</td>
#       <td>908</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>waxed_exposed_cut_copper_stairs_from_honeycomb</td>
#       <td>103</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>orange_banner</td>
#       <td>1088</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>blue_candle</td>
#       <td>1202</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>vex_armor_trim_smithing_template</td>
#       <td>1225</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>mangrove_trapdoor</td>
#       <td>708</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>cooked_rabbit</td>
#       <td>1073</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>waxed_cut_copper_slab_from_honeycomb</td>
#       <td>106</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>dark_oak_stairs</td>
#       <td>367</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>diorite_wall_from_diorite_stonecutting</td>
#       <td>389</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>cut_red_sandstone_slab</td>
#       <td>254</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>dye_light_blue_carpet</td>
#       <td>427</td>
#     </tr>
#     <tr>
#       <th>70</th>
#       <td>exposed_cut_copper_from_exposed_copper_stonecutting</td>
#       <td>83</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>orange_stained_glass_pane_from_glass_pane</td>
#       <td>466</td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td>stone_bricks_from_stone_stonecutting</td>
#       <td>318</td>
#     </tr>
#     <tr>
#       <th>73</th>
#       <td>pink_carpet</td>
#       <td>430</td>
#     </tr>
#     <tr>
#       <th>74</th>
#       <td>beacon</td>
#       <td>374</td>
#     </tr>
#     <tr>
#       <th>75</th>
#       <td>birch_wood</td>
#       <td>146</td>
#     </tr>
#     <tr>
#       <th>76</th>
#       <td>netherite_ingot</td>
#       <td>775</td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td>dye_red_wool</td>
#       <td>194</td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td>mossy_stone_brick_slab</td>
#       <td>619</td>
#     </tr>
#     <tr>
#       <th>79</th>
#       <td>tide_armor_trim_smithing_template</td>
#       <td>1226</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>dye_cyan_carpet</td>
#       <td>433</td>
#     </tr>
#     <tr>
#       <th>81</th>
#       <td>spruce_stairs</
