# %%
import pandas as pd
from pygments import highlight
from pygments.lexers import SparqlLexer
from pygments.formatters import HtmlFormatter
from IPython.display import HTML
from rdflib import Graph

def run_query(graph, query_path):
    try:
        with open(query_path, 'r') as file:
            query = file.read()
    except Exception as _e:
        print(f"No file for {query_path}")
        return
    results = graph.query(query)
    # Display the SPARQL query
    formatted_query = highlight(query, SparqlLexer(), HtmlFormatter(style='solarized-dark', full=True, nobackground=True))
    display(HTML(formatted_query))
    # Convert results to a Pandas DataFrame
    res_list = []
    for row in results:
        res_list.append([str(item) for item in row])
    df = pd.DataFrame(res_list, columns=[str(var) for var in results.vars]) if len(res_list) > 0 else pd.DataFrame()
    # Display the DataFrame as a table in Jupyter Notebook
    display(HTML(df.to_html()))

g = Graph(store="Oxigraph")
g.parse("minecraft.ttl")

print(f"Working with {len(g)} triples")
# Out:
# Working with 33646 triples

# %%
# Run a query
run_query(g, "queries/test.rq")
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2023 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: #586e75; background-color: #073642; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# span.linenos.special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# body .hll { background-color: #073642 }
# body .c { color: #586e75; font-style: italic } /* Comment */
# body .err { color: #839496; background-color: #dc322f } /* Error */
# body .esc { color: #839496 } /* Escape */
# body .g { color: #839496 } /* Generic */
# body .k { color: #859900 } /* Keyword */
# body .l { color: #839496 } /* Literal */
# body .n { color: #839496 } /* Name */
# body .o { color: #586e75 } /* Operator */
# body .x { color: #839496 } /* Other */
# body .p { color: #839496 } /* Punctuation */
# body .ch { color: #586e75; font-style: italic } /* Comment.Hashbang */
# body .cm { color: #586e75; font-style: italic } /* Comment.Multiline */
# body .cp { color: #d33682 } /* Comment.Preproc */
# body .cpf { color: #586e75 } /* Comment.PreprocFile */
# body .c1 { color: #586e75; font-style: italic } /* Comment.Single */
# body .cs { color: #586e75; font-style: italic } /* Comment.Special */
# body .gd { color: #dc322f } /* Generic.Deleted */
# body .ge { color: #839496; font-style: italic } /* Generic.Emph */
# body .ges { color: #839496; font-weight: bold; font-style: italic } /* Generic.EmphStrong */
# body .gr { color: #dc322f } /* Generic.Error */
# body .gh { color: #839496; font-weight: bold } /* Generic.Heading */
# body .gi { color: #859900 } /* Generic.Inserted */
# body .go { color: #839496 } /* Generic.Output */
# body .gp { color: #268bd2; font-weight: bold } /* Generic.Prompt */
# body .gs { color: #839496; font-weight: bold } /* Generic.Strong */
# body .gu { color: #839496; text-decoration: underline } /* Generic.Subheading */
# body .gt { color: #268bd2 } /* Generic.Traceback */
# body .kc { color: #2aa198 } /* Keyword.Constant */
# body .kd { color: #2aa198 } /* Keyword.Declaration */
# body .kn { color: #cb4b16 } /* Keyword.Namespace */
# body .kp { color: #859900 } /* Keyword.Pseudo */
# body .kr { color: #859900 } /* Keyword.Reserved */
# body .kt { color: #b58900 } /* Keyword.Type */
# body .ld { color: #839496 } /* Literal.Date */
# body .m { color: #2aa198 } /* Literal.Number */
# body .s { color: #2aa198 } /* Literal.String */
# body .na { color: #839496 } /* Name.Attribute */
# body .nb { color: #268bd2 } /* Name.Builtin */
# body .nc { color: #268bd2 } /* Name.Class */
# body .no { color: #268bd2 } /* Name.Constant */
# body .nd { color: #268bd2 } /* Name.Decorator */
# body .ni { color: #268bd2 } /* Name.Entity */
# body .ne { color: #268bd2 } /* Name.Exception */
# body .nf { color: #268bd2 } /* Name.Function */
# body .nl { color: #268bd2 } /* Name.Label */
# body .nn { color: #268bd2 } /* Name.Namespace */
# body .nx { color: #839496 } /* Name.Other */
# body .py { color: #839496 } /* Name.Property */
# body .nt { color: #268bd2 } /* Name.Tag */
# body .nv { color: #268bd2 } /* Name.Variable */
# body .ow { color: #859900 } /* Operator.Word */
# body .pm { color: #839496 } /* Punctuation.Marker */
# body .w { color: #839496 } /* Text.Whitespace */
# body .mb { color: #2aa198 } /* Literal.Number.Bin */
# body .mf { color: #2aa198 } /* Literal.Number.Float */
# body .mh { color: #2aa198 } /* Literal.Number.Hex */
# body .mi { color: #2aa198 } /* Literal.Number.Integer */
# body .mo { color: #2aa198 } /* Literal.Number.Oct */
# body .sa { color: #2aa198 } /* Literal.String.Affix */
# body .sb { color: #2aa198 } /* Literal.String.Backtick */
# body .sc { color: #2aa198 } /* Literal.String.Char */
# body .dl { color: #2aa198 } /* Literal.String.Delimiter */
# body .sd { color: #586e75 } /* Literal.String.Doc */
# body .s2 { color: #2aa198 } /* Literal.String.Double */
# body .se { color: #2aa198 } /* Literal.String.Escape */
# body .sh { color: #2aa198 } /* Literal.String.Heredoc */
# body .si { color: #2aa198 } /* Literal.String.Interpol */
# body .sx { color: #2aa198 } /* Literal.String.Other */
# body .sr { color: #cb4b16 } /* Literal.String.Regex */
# body .s1 { color: #2aa198 } /* Literal.String.Single */
# body .ss { color: #2aa198 } /* Literal.String.Symbol */
# body .bp { color: #268bd2 } /* Name.Builtin.Pseudo */
# body .fm { color: #268bd2 } /* Name.Function.Magic */
# body .vc { color: #268bd2 } /* Name.Variable.Class */
# body .vg { color: #268bd2 } /* Name.Variable.Global */
# body .vi { color: #268bd2 } /* Name.Variable.Instance */
# body .vm { color: #268bd2 } /* Name.Variable.Magic */
# body .il { color: #2aa198 } /* Literal.Number.Integer.Long */
#
#   </style>
# </head>
# <body>
# <h2></h2>
#
# <div class="highlight"><pre><span></span><span class="k">PREFIX</span> <span class="nn">mc</span><span class="p">:</span> <span class="nl">&lt;http://example.org/minecraft/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">mc_block</span><span class="p">:</span> <span class="nl">&lt;http://example.org/minecraft/block/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">mc_block_drop</span><span class="p">:</span> <span class="nl">&lt;http://example.org/minecraft/block_drop/&gt;</span>
# <span class="k">PREFIX</span> <span class="nn">rdf</span><span class="p">:</span> <span class="nl">&lt;http://www.w3.org/1999/02/22-rdf-syntax-ns#&gt;</span>
#
# <span class="k">SELECT</span> <span class="nv">?blockName</span> <span class="nv">?droppedItemName</span> <span class="nv">?silkTouch</span>
# <span class="k">WHERE</span> <span class="p">{</span>
#   <span class="nv">?block</span> <span class="nn">rdf</span><span class="p">:</span><span class="nt">type</span> <span class="nn">mc</span><span class="p">:</span><span class="nt">Block</span> <span class="p">.</span>
#   <span class="nv">?block</span> <span class="nn">mc_block</span><span class="p">:</span><span class="nt">hasName</span> <span class="nv">?blockName</span> <span class="p">.</span>
#   <span class="nv">?block</span> <span class="nn">mc_block</span><span class="p">:</span><span class="nt">hasDrop</span> <span class="nv">?drop</span> <span class="p">.</span>
#   <span class="nv">?drop</span> <span class="nn">rdf</span><span class="p">:</span><span class="nt">type</span> <span class="nn">mc</span><span class="p">:</span><span class="nt">BlockLoot</span> <span class="p">.</span>
#   <span class="nv">?drop</span> <span class="nn">mc_block_drop</span><span class="p">:</span><span class="nt">hasItem</span> <span class="nv">?droppedItem</span> <span class="p">.</span>
#   <span class="nv">?droppedItem</span> <span class="nn">mc_item</span><span class="p">:</span><span class="nt">hasName</span> <span class="nv">?droppedItemName</span> <span class="p">.</span>
#   <span class="nv">?drop</span> <span class="nn">mc_block_drop</span><span class="p">:</span><span class="nt">hasSilkTouchRule</span> <span class="nv">?silkTouch</span> <span class="p">.</span>
#   <span class="k">FILTER</span><span class="p">(</span><span class="nv">?silkTouch</span> <span class="o">=</span> <span class="s">&quot;required&quot;</span><span class="o">^^</span><span class="nn">xsd</span><span class="p">:</span><span class="nt">string</span><span class="p">)</span>
# <span class="p">}</span>
# </pre></div>
# </body>
# </html>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>blockName</th>
#       <th>droppedItemName</th>
#       <th>silkTouch</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>pink_stained_glass_pane</td>
#       <td>pink_stained_glass_pane</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>white_stained_glass</td>
#       <td>white_stained_glass</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>infested_chiseled_stone_bricks</td>
#       <td>chiseled_stone_bricks</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>small_amethyst_bud</td>
#       <td>small_amethyst_bud</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>turtle_egg</td>
#       <td>turtle_egg</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>red_stained_glass_pane</td>
#       <td>red_stained_glass_pane</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>redstone_ore</td>
#       <td>redstone_ore</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>infested_stone</td>
#       <td>stone</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>purple_stained_glass</td>
#       <td>purple_stained_glass</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>dead_brain_coral</td>
#       <td>dead_brain_coral</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>infested_cracked_stone_bricks</td>
#       <td>cracked_stone_bricks</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>melon</td>
#       <td>melon</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>yellow_stained_glass</td>
#       <td>yellow_stained_glass</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>iron_ore</td>
#       <td>iron_ore</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>coal_ore</td>
#       <td>coal_ore</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>blue_stained_glass_pane</td>
#       <td>blue_stained_glass_pane</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>mycelium</td>
#       <td>mycelium</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>deepslate_diamond_ore</td>
#       <td>deepslate_diamond_ore</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>deepslate_gold_ore</td>
#       <td>deepslate_gold_ore</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>glass</td>
#       <td>glass</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>red_stained_glass</td>
#       <td>red_stained_glass</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>grass_block</td>
#       <td>grass_block</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>infested_cobblestone</td>
#       <td>cobblestone</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>amethyst_cluster</td>
#       <td>amethyst_cluster</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>ender_chest</td>
#       <td>ender_chest</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>diamond_ore</td>
#       <td>diamond_ore</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>green_stained_glass_pane</td>
#       <td>green_stained_glass_pane</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>copper_ore</td>
#       <td>copper_ore</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>dead_tube_coral</td>
#       <td>dead_tube_coral</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>sculk_shrieker</td>
#       <td>sculk_shrieker</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>light_blue_stained_glass</td>
#       <td>light_blue_stained_glass</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>calibrated_sculk_sensor</td>
#       <td>calibrated_sculk_sensor</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>dead_horn_coral_fan</td>
#       <td>dead_horn_coral_fan</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>dead_bubble_coral_fan</td>
#       <td>dead_bubble_coral_fan</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>gravel</td>
#       <td>gravel</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>pink_stained_glass</td>
#       <td>pink_stained_glass</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>infested_mossy_stone_bricks</td>
#       <td>mossy_stone_bricks</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>dead_fire_coral_fan</td>
#       <td>dead_fire_coral_fan</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>sculk_sensor</td>
#       <td>sculk_sensor</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>brown_mushroom_block</td>
#       <td>brown_mushroom_block</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>blue_stained_glass</td>
#       <td>blue_stained_glass</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>dead_fire_coral</td>
#       <td>dead_fire_coral</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>nether_quartz_ore</td>
#       <td>nether_quartz_ore</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>black_stained_glass</td>
#       <td>black_stained_glass</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>sea_lantern</td>
#       <td>sea_lantern</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>deepslate_iron_ore</td>
#       <td>deepslate_iron_ore</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>crimson_nylium</td>
#       <td>crimson_nylium</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>infested_deepslate</td>
#       <td>deepslate</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>soul_campfire</td>
#       <td>soul_campfire</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>bookshelf</td>
#       <td>bookshelf</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>deepslate_redstone_ore</td>
#       <td>deepslate_redstone_ore</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>chiseled_bookshelf</td>
#       <td>chiseled_bookshelf</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>campfire</td>
#       <td>campfire</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>bee_nest</td>
#       <td>bee_nest</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>fire_coral</td>
#       <td>fire_coral</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>horn_coral_fan</td>
#       <td>horn_coral_fan</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>deepslate_emerald_ore</td>
#       <td>deepslate_emerald_ore</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>clay</td>
#       <td>clay</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>sculk</td>
#       <td>sculk</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>yellow_stained_glass_pane</td>
#       <td>yellow_stained_glass_pane</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>ice</td>
#       <td>ice</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>deepslate_copper_ore</td>
#       <td>deepslate_copper_ore</td>
#       <td>required</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>light_blue_stained_glass_pane</td>
#       <td>light_blue_stained_glass_pane</td>
#       <td>requir
